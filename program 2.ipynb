# %%
num=int(input())
if num>0:
    print("number is positive")
elif num<0:
    print("number is negative")
elif num==0:
    print("number is 0")
# Out:
#  4
# number is positive

# %%
year=int(input("enter a year:"))
if(year%4==0 and year%100!=0) or (year%400==0):
    print("leap year")
else:
    print("not a leap year")
# Out:
# enter a year: 2007
# not a leap year

# %%
a=int(input("enter the first number"))
b=int(input("enter the secound number"))
op=input("enter the opertional symbol for the calucation:")
if op=="+":
         print("result:",a+b)
elif op=="-":
             print("result:",a-b)
elif op=="*":
             print("result:",a*b)
elif op=="/":
             print("result:",a/b)
elif op=="%":
             print("result:",a%b)
else:
    print("invalid operator")
# Out:
# enter the first number 5
# enter the secound number 9
# enter the opertional symbol for the calucation: +
# result: 14

# %%
ch=input("enter the alphabet")
if ch in('a','e','i','o','u','A','E','I','O','U'):
    print("vowel")
else:
    print("consonant")
# Out:
# enter the alphabet t
# consonant

# %%
marks=float(input("enter marks:"))
if marks>=90:
    print("grade A")
elif marks>=75:
    print("Grade B")
elif marks>=50:
    print("Grade C")
else:
    print("fail")
# Out:
# enter marks: 67
# Grade C

# %%
num=int(input("enter a number:"))
if num%5==0 and num%11==0:
    print("divisible by both 5 and 11")
else:
    print("not divisible by both 5 and 11")
# Out:
# enter a number: 89
# not divisible by both 5 and 11

# %%
ch=input("enbter a character:")
if ch.isalpha():
    print("alphabet")
elif ch.isdigit():
    print("digit")
else:
    print("special character")
# Out:
# enbter a character: 5
# digit

# %%
num=int(input("enter a number:"))
fact=1
if num<0:
    print("factorial not possible")
else:
    for i in range(1, num+1):
        fact=fact*i
        print("factorial =",fact)
# Out:
# enter a number: 9
# factorial = 1
# factorial = 2
# factorial = 6
# factorial = 24
# factorial = 120
# factorial = 720
# factorial = 5040
# factorial = 40320
# factorial = 362880

# %%
num=int(input("enter a number:"))
if num%3==0:
    print("divisible by 3")
else:
    print("not divisible by 3")
# Out:
# enter a number: 7
# not divisible by 3

# %%
p=float(input("enter principal"))
r=float(input("enter rate"))
t=float(input("enter time"))
si=(p*r*t)/100
print("simple interest is= ",si)
# Out:
# enter principal 900000
# enter rate 6.5
# enter time 1
# simple interest is=  58500.0
