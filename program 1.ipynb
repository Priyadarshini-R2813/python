# %%
print("priyaa")
# Out:
# priyaa

# %%
a=20
b=30
sum=a+b
print(sum)
# Out:
# 50

# %%
p=23000
t=2
r=5
si=p*t*r/100
print(si)
# Out:
# 2300.0

# %%
p=float(input("enter principle amount"))
t=int(input("enter time"))
r=int(input("interest percentage"))
si=p*t*r/100
print(si)
# Out:
# enter principle amount 2300.5
# enter time 2
# interest percentage 5
# 230.05
